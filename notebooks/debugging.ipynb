# %%
import torch

import os.path as osp

from glob import glob 

import cv2 
import matplotlib.pyplot as plt

# %%
img_list[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_21414/680553571.py in <module>
# ----> 1 img_list[0]
#
# NameError: name 'img_list' is not defined

# %%
ann_list[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_21414/2881923151.py in <module>
# ----> 1 ann_list[0]
#
# NameError: name 'ann_list' is not defined

# %%
img_path = '/home/user/UOS-SSaS Dropbox/05. Data/00. Benchmarks/02. PASCAL VOC/VOCdevkit/VOC2012/JPEGImages'

img_list = glob(osp.join(img_path, '*.jpg'))
idx = 10
img = cv2.imread(img_list[idx])
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
print(len(img_list))
# Out:
# 17125

# %%
ann_path = '/home/user/UOS-SSaS Dropbox/05. Data/00. Benchmarks/02. PASCAL VOC/VOCdevkit/VOC2012/Annotations'

ann_list = glob(osp.join(ann_path, '*'))
len(ann_list)
# Out:
# 17125

# %%
import xmltodict

def read_xml(path):
    

    with open(path) as file:
        file_data = file.read()
        dict_data = xmltodict.parse(file_data)

    return dict_data

# %%
# Out:
# [{'name': 'car',
#   'pose': 'Rear',
#   'truncated': '0',
#   'occluded': '0',
#   'bndbox': {'xmin': '154', 'ymin': '160', 'xmax': '275', 'ymax': '232'},
#   'difficult': '0'},
#  {'name': 'aeroplane',
#   'pose': 'Left',
#   'truncated': '1',
#   'occluded': '0',
#   'bndbox': {'xmin': '12', 'ymin': '30', 'xmax': '500', 'ymax': '174'},
#   'difficult': '0'}]

# %%
# Out:
# {'annotation': {'filename': '2010_006125.jpg', 'folder': 'VOC2010', 'object': {'name': 'person', 'bndbox': {'xmax': '358', 'xmin': '32', 'ymax': '375', 'ymin': '1'}, 'difficult': '0', 'pose': 'Unspecified', 'actions': {'phoning': '0', 'playinginstrument': '0', 'reading': '0', 'ridingbike': '0', 'ridinghorse': '0', 'running': '0', 'takingphoto': '1', 'usingcomputer': '0', 'walking': '0', 'jumping': '0', 'other': '0'}, 'point': {'x': '121', 'y': '205'}}, 'segmented': '0', 'size': {'depth': '3', 'height': '375', 'width': '500'}, 'source': {'annotation': 'PASCAL VOC2010', 'database': 'The VOC2010 Database', 'image': 'flickr'}}}

# %%
import sys

sys.path.append('../')

import matplotlib.pyplot as plt 
import cv2

from datasets.pascal_voc import PASCALVOCDataset

root_dir = '/home/user/UOS-SSaS Dropbox/05. Data/00. Benchmarks/02. PASCAL VOC/VOCdevkit/VOC2012'
dataset = PASCALVOCDataset(root_dir=root_dir)

# %%
from random import randint 

idx = randint(0, len(dataset))

img, bboxes = dataset[idx]

for bbox in bboxes:
    start_point = bbox[1], bbox[2]
    end_point = bbox[3], bbox[4]

    img = cv2.rectangle(img, start_point, end_point, (255, 0, 0), 2)

plt.imshow(img)
